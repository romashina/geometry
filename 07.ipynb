# %% [markdown]
# <a href="https://colab.research.google.com/github/romashina/geometry/blob/main/07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Геометрия
#
# **Геометрия** (*греч.*: **гео** - земля, **метрео** - мерить) - землемерие. Наука, занимающаяся изучением фигур. Она состоит:
#
# - **Планиметрия** - фигуры на плоскости
# - **Стереометрия** - фигуры в пространстве
#
# ## 1. Прямая и отрезок
#
#
#
# **Прямая** - это бесконечная в обе стороны линяя, на бумаге нарисова только ее часть, обозначенная либо строчными латинскими буквами (a, b, c)

# %%
print("hello world")
