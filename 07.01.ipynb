# %% [markdown]
# 1. Проведите прямую, обозначьте её буквой $а$ и отметьте точки $A$ и $B$, лежащие на этой прямой, и точки Р, Q и R, не лежащие на ней. Опишите взаимное расположение точек А, В, Р, Q, R и прямой а, используя символы ∈ и ∉.
# ![0001](./img/0001.svg)
#
# **Ответ**: $A\in a, B\in a, R\not\in a, Q\not\in a, R\not\in a$

# %% [markdown]
# 2. Отметьте три точки $A$, $B$ и $C$, не лежащие на одной прямой, и через каждую пару точек проведите прямую. Сколько прямых получилось?
#
# ![0002](./img/0002.svg)
#
# **Ответ**: Получились 3 прямые.

# %% [markdown]
# 3. Проведите три прямые так, чтобы каждые две из них пересекались. Обозначьте все точки пересечения этих прямых. Сколько получилось точек? Рассмотрите все возможные случаи.
#
# ![0003](./img/0003.svg)
#
# **Ответ**:
#
# - Если три прямые попарно пересекаются и никакие две не совпадают, то точек пересечения будет 3.
# - Если две прямые параллельны, то получится 2 точки пересечения;
# - Если все три прямые проходят через одну точку, то получится 1 точка; если все три прямые совпадают, то получится бесконечно много точек.

# %% [markdown]
# 4. Отметьте точки A, B, C, D так, чтобы точки A, B, C лежали на одной прямой, а точка D не лежала на ней. Через каждые две точки проведите прямую. Сколько получилось прямых?
#
# ![4 lines](img/0004.svg)
#
# **Ответ**: получилось 4 прямых.

# %% [markdown]
# 5. Проведите прямую а и отметьте на ней точки A и B. Отметьте:
# - а. точки М и N, лежащие на отрезке AB;
# - б. точки Р и Q, лежащие на прямой а, но не лежащие на отрезке AB;
# - в. точки R и S, не лежащие на прямой а.
#
# ![0005](img/0005.svg)

# %% [markdown]
# 6. Проведите прямую и отметьте на ней три точки. Сколько отрезков получилось на прямой?
#
# ![6](img/0006.svg)
#
# **Ответ**: 2 отрезка на прямой

# %% [markdown]
# 7. На рисунке 14 изображена прямая, на ней отмечены точки A, B, C и D. Назовите все отрезки:
# - а. на которых лежит точка С;
# - б. на которых не лежит точка В.
#
# ![7](img/0007.svg)
#
# **Ответ**:
# - а. AC, AD, BC, BD, CD
# - б. CD

# %% [markdown]
# 8. Начертите ломаную из трёх звеньев, которая:
#
# - а. является замкнутой
# - б. не является замкнутой.
#
# **Ответ**:
#
# ![0008](./img/0008.svg)

# %% [markdown]
# 9. Цифры почтового индекса записываются по определённым правилам (рис. 15) для удобства распознавания сортировочным автоматом.
#
# ![9](img/0009.svg)
#
# - а. Укажите на рисунке цифры, в записи которых используются ломаные.
# - б. Сколько звеньев у каждой ломаной? Укажите замкнутую ломаную.
# - в. Как называется многоугольник, образованный на рисунке замкнутой ломаной?
#
# **Ответ**:
#
# - а. Все цифры могут быть образованы с помощью ломанной линии
# - б.:
#
# Цифра   | Звенья
# --      | --
# 1       | 2
# 2       | 4
# 3       | 4
# 4       | 4
# 5       | 5
# 6       | 5
# 7       | 3
# 8       | 7
# 9       | 5
# 0       | 4
#
# - в. Ломанная цифры 0 (ноль) образует прямоугольник

# %% [markdown]
# 10. Начертите пятиугольник, как на рисунке 9.
#
# - a. Разбейте его на треугольники так, чтобы у пятиугольника и каждого треугольника были общие стороны.
# - b. Сколько треугольников может получиться на чертеже?
# - c. Какие ещё многоугольники получились на чертеже?

# %%
# # Координаты середины отрезка EB
# E = (20, 140)
# B = (180, 120)
# C = (130, 200)
# # Считаем середину через генератор или распаковку
# print(f"F{tuple((a + b) / 2 for a, b in zip(E, B))}")
# print(f"F{tuple((a + b) / 2 for a, b in zip(E, C))}")
def bias(a: tuple[int, int], b: tuple[int, int], t: float) -> tuple[float, float]:
    """Возвращает координаты точки на отрезке AB со смещением t относительно точки B
    :param a: координаты точки A в виде кортежа (x, y)
    :param b: координаты точки B в виде кортежа (x, y)
    :param t: смещение точки B ближе к A (0 <= t <= 1), например 0,9 - 90% отрезка AB
              отдаление точки В в от точки A (t > 1) 
    :return: координаты точки F в виде кортежа (x, y)
    """
    return (a[0] +(b[0] - a[0]) * t, a[1] +(b[1] - a[1]) * t)

bias((20, 140), (180, 120), 0.5)
# Out:
# (100.0, 130.0)

# %% [markdown]
# **Ответ**::
#
# - a.
#
# ![10](img/0010.svg)
#
# - b. 5 треугольников в одном пятиугольнике
# - c. 4-угольник, 6-угольник, 7-угольник

# %% [markdown]
# 11. Проведите прямую, отметьте на ней точки A и B и на отрезке AB отметьте точку С.
#
# ![11](img/0011.svg)
#
# - а. Среди лучей AB, ВС, СА, АС и ВА на зовите совпадающие лучи;
# - б. назовите луч, который является продолжением луча СА.
#
# **Ответ**:
#
# - а. Совпадающие лучи:
#     - AB, AC
#     - BC, BA
# - б. Продолжением луча CA является луч CB

# %% [markdown]
# 12. Начертите три неразвёрнутых угла и обозначьте их так: ∠AOB, ∠hk, ∠M.
#
# **Ответ**:
#
# ![12](img/0012.svg)

# %% [markdown]
# 13. Начертите два развёрнутых угла и обозначьте их буквами.
#
# **Ответ**:
#
# ![13](img/0013.svg)

# %% [markdown]
# 14. Начертите три луча h, k и l с общим началом. Назовите все углы, образованные данными лучами.
#
# ![14](img/0014.svg)
#
# **Ответ**: $\angle hk,\ \angle kl,\ \angle hl$

# %% [markdown]
# 15. Начертите неразвёрнутый угол hk. Отметьте две точки внутри этого угла, две точки вне этого угла и две точки на сторонах угла.
#
# ![15](img/0015.svg)

# %% [markdown]
# 16. Начертите неразвёрнутый угол. Отметьте точки А, В, М и N так, чтобы все точки отрезка AB лежали внутри угла, а все точки отрезка MN лежали вне угла.
#
# **Ответ**:
#
# ![16](img/0016.svg)

# %% [markdown]
# 17. Начертите неразвёрнутый угол AOB и проведите:
#
# - а. луч ОС, который делит угол AOB на два угла;
# - б. луч OD, который не делит угол АОС на два угла.

# %%
bias((10, 110), (30, 60), 1.7)
# Out:
# (44.0, 25.0)

# %% [markdown]
# **Ответ**:
#
# ![17](img/0017.svg)
